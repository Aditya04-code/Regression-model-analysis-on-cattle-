# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./ABBREV.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0          BUTTER,WITH SALT      15.87         717         0.85
# 1  BUTTER,WHIPPED,WITH SALT      15.87         717         0.85
# 2      BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3               CHEESE,BLUE      42.41         353        21.40
# 4              CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          81.11     2.11            0.06           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#    Calcium_(mg)  ...  Vit_K_(æg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# 0          24.0  ...         7.0      51.368       21.021        3.043
# ...

# %%
df.describe()
# Out:
#          Water_(g)   Energ_Kcal  Protein_(g)  Lipid_Tot_(g)      Ash_(g)  \
# count  8612.000000  8618.000000   8618.00000    8618.000000  8286.000000
# mean     54.163710   226.438617     11.52391      10.647024     1.816169
# std      30.648283   169.388910     10.55059      15.866353     3.035264
# min       0.000000     0.000000      0.00000       0.000000     0.000000
# 25%      30.087500    93.000000      2.47000       0.992500     0.860000
# 50%      63.265000   191.000000      8.28500       5.235000     1.200000
# 75%      77.610000   336.000000     19.97750      13.900000     2.140000
# max     100.000000   902.000000     88.32000     100.000000    99.800000
#
#        Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)    Iron_(mg)  \
# count     8618.000000   7962.000000    6679.000000   8264.000000  8471.000000
# mean        21.819062      2.189940       8.464779     76.556026     2.743569
# ...

# %%
df.columns
# Out:
# Index(['Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)', 'Lipid_Tot_(g)',
#        'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)', 'Sugar_Tot_(g)',
#        'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)', 'Phosphorus_(mg)',
#        'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)', 'Copper_mg)',
#        'Manganese_(mg)', 'Selenium_(æg)', 'Vit_C_(mg)', 'Thiamin_(mg)',
#        'Riboflavin_(mg)', 'Niacin_(mg)', 'Panto_Acid_mg)', 'Vit_B6_(mg)',
#        'Folate_Tot_(æg)', 'Folic_Acid_(æg)', 'Food_Folate_(æg)',
#        'Folate_DFE_(æg)', 'Choline_Tot_ (mg)', 'Vit_B12_(æg)', 'Vit_A_IU',
#        'Vit_A_RAE', 'Retinol_(æg)', 'Alpha_Carot_(æg)', 'Beta_Carot_(æg)',
#        'Beta_Crypt_(æg)', 'Lycopene_(æg)', 'Lut+Zea_ (æg)', 'Vit_E_(mg)',
#        'Vit_D_æg', 'Vit_D_IU', 'Vit_K_(æg)', 'FA_Sat_(g)', 'FA_Mono_(g)',
#        'FA_Poly_(g)', 'Cholestrl_(mg)', 'GmWt_1', 'GmWt_Desc1', 'GmWt_2',
#        'GmWt_Desc2', 'Refuse_Pct'],
#       dtype='object')

# %%
df.corr()
# Out:
#                    Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# Water_(g)           1.000000   -0.898084    -0.104671      -0.485618
# Energ_Kcal         -0.898084    1.000000     0.110302       0.806795
# Protein_(g)        -0.104671    0.110302     1.000000       0.054715
# Lipid_Tot_(g)      -0.485618    0.806795     0.054715       1.000000
# Ash_(g)            -0.277653    0.109001     0.096849       0.001061
# Carbohydrt_(g)     -0.772190    0.487096    -0.301974      -0.054116
# Fiber_TD_(g)       -0.394252    0.199382    -0.081044      -0.034200
# Sugar_Tot_(g)      -0.509061    0.349315    -0.305234      -0.006830
# Calcium_(mg)       -0.265328    0.142863     0.038781       0.021453
# Iron_(mg)          -0.356509    0.198804     0.122030      -0.040825
# Magnesium_(mg)     -0.400137    0.259074     0.205916       0.067887
# Phosphorus_(mg)    -0.283645    0.184937     0.432260       0.056178
# Potassium_(mg)     -0.198754    0.073294     0.243926      -0.048891
# ...

# %%
import matplotlib.pyplot as plt
ax, fig = plt.subplots(figsize=[15,7])
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
